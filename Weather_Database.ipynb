# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
# Import the API key.
from config import g_key
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=aed867660a1ac3c03ada583c4a7694cb

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | chumikan
# Processing Record 3 of Set 1 | aklavik
# Processing Record 4 of Set 1 | morant bay
# Processing Record 5 of Set 1 | mazagao
# Processing Record 6 of Set 1 | nyurba
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | moree
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | praia da vitoria
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | leova
# Processing Record 13 of Set 1 | valencia
# Processing Record 14 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | guryevsk
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | norman wells
# Processing Record 19 of Set 1 | urubicha
# Processing Record 20 of Set 1 | saravan
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | odder
# Processing Record 27 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 1 | nelson bay
# Processing Record 34 of Set 1 | inza
# Processing Record 35 of Set 1 | ginir
# Processing Record 36 of Set 1 | skjervoy
# Processing Record 37 of Set 1 | provideniya
# Processing Record 38 of Set 1 | broome
# Processing Record 39 of Set 1 | bathsheba
# Processing Record 40 of Set 1 | union city
# Processing Record 41 of Set 1 | half moon bay
# Processing Record 42 of Set 1 | marolambo
# Processing Record 43 of Set 1 | tupik
# Processing Record 44 of Set 1 | port hawkesbury
# Processing Record 45 of Set 1 | naral
# City not found. Skipping...
# Processing Record 46 of Set 1 | ndele
# Processing Record 47 of Set 1 | sambava
# Processing Record 48 of Set 1 | la palma
# Processing Record 49 of Set 1 | cayenne
# Processing Record 50 of Set 1 | tromso
# Processing Record 1 of Set 2 | burnie
# Processing Record 2 of Set 2 | vicksburg
# Processing Record 3 of Set 2 | san cristobal
# Processing Record 4 of Set 2 | rikitea
# Processing Record 5 of Set 2 | bosaso
# Processing Record 6 of Set 2 | srednekolymsk
# Processing Record 7 of Set 2 | lorengau
# Processing Record 8 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | yar-sale
# Processing Record 11 of Set 2 | omaruru
# Processing Record 12 of Set 2 | omboue
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | itarema
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | clyde river
# Processing Record 17 of Set 2 | tonneins
# Processing Record 18 of Set 2 | atuona
# Processing Record 19 of Set 2 | saskylakh
# Processing Record 20 of Set 2 | hofn
# Processing Record 21 of Set 2 | el faiyum
# City not found. Skipping...
# Processing Record 22 of Set 2 | punta arenas
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | kidal
# Processing Record 25 of Set 2 | yamada
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | chuy
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | sisimiut
# Processing Record 31 of Set 2 | oakland
# Processing Record 32 of Set 2 | saint anthony
# Processing Record 33 of Set 2 | sirfa
# City not found. Skipping...
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | erenhot
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | lasa
# Processing Record 39 of Set 2 | alofi
# Processing Record 40 of Set 2 | fulitun
# City not found. Skipping...
# Processing Record 41 of Set 2 | kedrovyy
# Processing Record 42 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 2 | hamilton
# Processing Record 44 of Set 2 | hasaki
# Processing Record 45 of Set 2 | sao filipe
# Processing Record 46 of Set 2 | weligama
# Processing Record 47 of Set 2 | vung tau
# Processing Record 48 of Set 2 | bethel
# Processing Record 49 of Set 2 | udachnyy
# Processing Record 50 of Set 2 | siatista
# Processing Record 1 of Set 3 | zhezkazgan
# Processing Record 2 of Set 3 | vila
# Processing Record 3 of Set 3 | kapaa
# Processing Record 4 of Set 3 | panjakent
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | klaksvik
# Processing Record 8 of Set 3 | cidreira
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | san patricio
# Processing Record 11 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 3 | charlestown
# Processing Record 13 of Set 3 | richards bay
# Processing Record 14 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 3 | leningradskiy
# Processing Record 16 of Set 3 | pimentel
# Processing Record 17 of Set 3 | vanavara
# Processing Record 18 of Set 3 | esperance
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | nemuro
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | mar del plata
# Processing Record 23 of Set 3 | soloneshnoye
# Processing Record 24 of Set 3 | belmonte
# Processing Record 25 of Set 3 | sorata
# Processing Record 26 of Set 3 | east london
# Processing Record 27 of Set 3 | pisco
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | rocha
# Processing Record 30 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 3 | lima
# Processing Record 32 of Set 3 | avarua
# Processing Record 33 of Set 3 | tiksi
# Processing Record 34 of Set 3 | gazanjyk
# Processing Record 35 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | pevek
# Processing Record 39 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 40 of Set 3 | bitung
# Processing Record 41 of Set 3 | takoradi
# Processing Record 42 of Set 3 | ikorodu
# Processing Record 43 of Set 3 | eyl
# Processing Record 44 of Set 3 | odoyev
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | ahipara
# Processing Record 47 of Set 3 | bandarbeyla
# Processing Record 48 of Set 3 | san carlos
# Processing Record 49 of Set 3 | airai
# Processing Record 50 of Set 3 | ilulissat
# Processing Record 1 of Set 4 | siquirres
# Processing Record 2 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 3 of Set 4 | lacey
# Processing Record 4 of Set 4 | caravelas
# Processing Record 5 of Set 4 | tombouctou
# Processing Record 6 of Set 4 | georgetown
# Processing Record 7 of Set 4 | namibe
# Processing Record 8 of Set 4 | nouadhibou
# Processing Record 9 of Set 4 | chebenki
# Processing Record 10 of Set 4 | kurdzhinovo
# Processing Record 11 of Set 4 | naze
# Processing Record 12 of Set 4 | pringsewu
# Processing Record 13 of Set 4 | mlimba
# Processing Record 14 of Set 4 | shamary
# Processing Record 15 of Set 4 | katsuura
# Processing Record 16 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 4 | carahue
# Processing Record 18 of Set 4 | teahupoo
# Processing Record 19 of Set 4 | snasa
# Processing Record 20 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 4 | poopo
# Processing Record 22 of Set 4 | solton
# Processing Record 23 of Set 4 | naspur
# Processing Record 24 of Set 4 | chiredzi
# Processing Record 25 of Set 4 | icara
# Processing Record 26 of Set 4 | bengkulu
# Processing Record 27 of Set 4 | fairbanks
# Processing Record 28 of Set 4 | ostrovnoy
# Processing Record 29 of Set 4 | sarahan
# Processing Record 30 of Set 4 | yakeshi
# Processing Record 31 of Set 4 | andenes
# Processing Record 32 of Set 4 | buchanan
# Processing Record 33 of Set 4 | castro
# Processing Record 34 of Set 4 | lata
# Processing Record 35 of Set 4 | sao joao da barra
# Processing Record 36 of Set 4 | longyearbyen
# Processing Record 37 of Set 4 | oussouye
# Processing Record 38 of Set 4 | saldus
# Processing Record 39 of Set 4 | surgut
# Processing Record 40 of Set 4 | talaya
# Processing Record 41 of Set 4 | fayetteville
# Processing Record 42 of Set 4 | yepifan
# Processing Record 43 of Set 4 | mchinji
# Processing Record 44 of Set 4 | ballina
# Processing Record 45 of Set 4 | shuyskoye
# Processing Record 46 of Set 4 | lapithos
# Processing Record 47 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 4 | fukue
# Processing Record 49 of Set 4 | touros
# Processing Record 50 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 1 of Set 5 | alvorada
# Processing Record 2 of Set 5 | genc
# Processing Record 3 of Set 5 | nisporeni
# Processing Record 4 of Set 5 | atar
# Processing Record 5 of Set 5 | carnarvon
# Processing Record 6 of Set 5 | hualmay
# Processing Record 7 of Set 5 | durango
# Processing Record 8 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 9 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 5 | kavieng
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | krasnovishersk
# Processing Record 13 of Set 5 | kabare
# Processing Record 14 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 5 | victoria
# Processing Record 16 of Set 5 | narsaq
# Processing Record 17 of Set 5 | sur
# Processing Record 18 of Set 5 | kariba
# Processing Record 19 of Set 5 | lipin bor
# Processing Record 20 of Set 5 | rongcheng
# Processing Record 21 of Set 5 | rawah
# Processing Record 22 of Set 5 | gejiu
# Processing Record 23 of Set 5 | saint george
# Processing Record 24 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 5 | pacasmayo
# Processing Record 26 of Set 5 | ancud
# Processing Record 27 of Set 5 | morro bay
# Processing Record 28 of Set 5 | meulaboh
# Processing Record 29 of Set 5 | severnoye
# Processing Record 30 of Set 5 | sun valley
# Processing Record 31 of Set 5 | saldanha
# Processing Record 32 of Set 5 | la ronge
# Processing Record 33 of Set 5 | pacifica
# Processing Record 34 of Set 5 | palauig
# Processing Record 35 of Set 5 | lisakovsk
# Processing Record 36 of Set 5 | ouango
# Processing Record 37 of Set 5 | chimbote
# Processing Record 38 of Set 5 | goderich
# Processing Record 39 of Set 5 | tuktoyaktuk
# Processing Record 40 of Set 5 | faya
# Processing Record 41 of Set 5 | kahului
# Processing Record 42 of Set 5 | rawson
# Processing Record 43 of Set 5 | kaeo
# Processing Record 44 of Set 5 | allanmyo
# City not found. Skipping...
# Processing Record 45 of Set 5 | pemba
# Processing Record 46 of Set 5 | kyzyl-suu
# Processing Record 47 of Set 5 | ta khmau
# Processing Record 48 of Set 5 | torbay
# Processing Record 49 of Set 5 | sitka
# Processing Record 50 of Set 5 | tabou
# Processing Record 1 of Set 6 | khatanga
# Processing Record 2 of Set 6 | samarai
# Processing Record 3 of Set 6 | changchun
# Processing Record 4 of Set 6 | faanui
# Processing Record 5 of Set 6 | sabang
# Processing Record 6 of Set 6 | khandyga
# Processing Record 7 of Set 6 | agsu
# City not found. Skipping...
# Processing Record 8 of Set 6 | rio gallegos
# Processing Record 9 of Set 6 | salinopolis
# Processing Record 10 of Set 6 | macapa
# Processing Record 11 of Set 6 | cedar rapids
# Processing Record 12 of Set 6 | fare
# Processing Record 13 of Set 6 | kruisfontein
# Processing Record 14 of Set 6 | brusturi
# Processing Record 15 of Set 6 | ashtabula
# Processing Record 16 of Set 6 | machico
# Processing Record 17 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 6 | ponta do sol
# Processing Record 19 of Set 6 | vanderhoof
# Processing Record 20 of Set 6 | tasiilaq
# Processing Record 21 of Set 6 | izumo
# Processing Record 22 of Set 6 | hambantota
# Processing Record 23 of Set 6 | parana
# Processing Record 24 of Set 6 | mandleshwar
# Processing Record 25 of Set 6 | vao
# Processing Record 26 of Set 6 | kavaratti
# Processing Record 27 of Set 6 | prachuap khiri khan
# Processing Record 28 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 6 | karratha
# Processing Record 30 of Set 6 | parintins
# Processing Record 31 of Set 6 | mosetse
# Processing Record 32 of Set 6 | koygorodok
# Processing Record 33 of Set 6 | sioux falls
# Processing Record 34 of Set 6 | pedernales
# Processing Record 35 of Set 6 | moranbah
# Processing Record 36 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 6 | pangnirtung
# Processing Record 38 of Set 6 | bo rai
# Processing Record 39 of Set 6 | dongying
# Processing Record 40 of Set 6 | loreto
# Processing Record 41 of Set 6 | vermillion
# Processing Record 42 of Set 6 | camopi
# Processing Record 43 of Set 6 | springbok
# Processing Record 44 of Set 6 | svetlogorsk
# Processing Record 45 of Set 6 | sayanskiy
# City not found. Skipping...
# Processing Record 46 of Set 6 | lebu
# Processing Record 47 of Set 6 | algiers
# Processing Record 48 of Set 6 | pilar do sul
# Processing Record 49 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 6 | constitucion
# Processing Record 1 of Set 7 | pudozh
# Processing Record 2 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 7 | dibulla
# Processing Record 5 of Set 7 | karpathos
# Processing Record 6 of Set 7 | cherskiy
# Processing Record 7 of Set 7 | bichena
# Processing Record 8 of Set 7 | coquimbo
# Processing Record 9 of Set 7 | ulagan
# Processing Record 10 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 7 | conceicao do araguaia
# Processing Record 12 of Set 7 | nhulunbuy
# Processing Record 13 of Set 7 | luau
# Processing Record 14 of Set 7 | leon
# Processing Record 15 of Set 7 | san carlos de bariloche
# Processing Record 16 of Set 7 | cabo san lucas
# Processing Record 17 of Set 7 | arlit
# Processing Record 18 of Set 7 | marsabit
# Processing Record 19 of Set 7 | zhicheng
# Processing Record 20 of Set 7 | medicine hat
# Processing Record 21 of Set 7 | gaoual
# Processing Record 22 of Set 7 | maniitsoq
# Processing Record 23 of Set 7 | roma
# Processing Record 24 of Set 7 | san isidro
# Processing Record 25 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 7 | lagoa
# Processing Record 27 of Set 7 | vardo
# Processing Record 28 of Set 7 | amapa
# Processing Record 29 of Set 7 | zhigansk
# Processing Record 30 of Set 7 | namatanai
# Processing Record 31 of Set 7 | itoman
# Processing Record 32 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 7 | huilong
# Processing Record 35 of Set 7 | acandi
# Processing Record 36 of Set 7 | dranceni sat
# City not found. Skipping...
# Processing Record 37 of Set 7 | bosobolo
# Processing Record 38 of Set 7 | byron bay
# Processing Record 39 of Set 7 | port keats
# Processing Record 40 of Set 7 | rudnytsya
# City not found. Skipping...
# Processing Record 41 of Set 7 | salalah
# Processing Record 42 of Set 7 | magadan
# Processing Record 43 of Set 7 | raga
# Processing Record 44 of Set 7 | jatiroto
# Processing Record 45 of Set 7 | aykhal
# Processing Record 46 of Set 7 | atocha
# Processing Record 47 of Set 7 | acapulco
# Processing Record 48 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 7 | batagay
# Processing Record 50 of Set 7 | smithers
# Processing Record 1 of Set 8 | road town
# Processing Record 2 of Set 8 | yebaishou
# Processing Record 3 of Set 8 | marsa matruh
# Processing Record 4 of Set 8 | vila velha
# Processing Record 5 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 6 of Set 8 | nha trang
# Processing Record 7 of Set 8 | haapiti
# Processing Record 8 of Set 8 | neuquen
# Processing Record 9 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 8 | ksenyevka
# City not found. Skipping...
# Processing Record 11 of Set 8 | pauini
# Processing Record 12 of Set 8 | san luis
# Processing Record 13 of Set 8 | monrovia
# Processing Record 14 of Set 8 | bugarama
# Processing Record 15 of Set 8 | gimli
# Processing Record 16 of Set 8 | anori
# Processing Record 17 of Set 8 | saint-pierre
# Processing Record 18 of Set 8 | penzance
# Processing Record 19 of Set 8 | jiuquan
# Processing Record 20 of Set 8 | calca
# Processing Record 21 of Set 8 | bilma
# Processing Record 22 of Set 8 | myre
# Processing Record 23 of Set 8 | fort nelson
# Processing Record 24 of Set 8 | kozloduj
# City not found. Skipping...
# Processing Record 25 of Set 8 | mount gambier
# Processing Record 26 of Set 8 | antalaha
# Processing Record 27 of Set 8 | orange
# Processing Record 28 of Set 8 | uddevalla
# Processing Record 29 of Set 8 | luderitz
# Processing Record 30 of Set 8 | flinders
# Processing Record 31 of Set 8 | rio grande
# Processing Record 32 of Set 8 | pacific grove
# Processing Record 33 of Set 8 | los llanos de aridane
# Processing Record 34 of Set 8 | aybak
# City not found. Skipping...
# Processing Record 35 of Set 8 | roberval
# Processing Record 36 of Set 8 | baneh
# Processing Record 37 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 8 | kamaishi
# Processing Record 39 of Set 8 | hammerfest
# Processing Record 40 of Set 8 | blagoyevo
# Processing Record 41 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 8 | saint-joseph
# Processing Record 43 of Set 8 | sainte-luce
# Processing Record 44 of Set 8 | tuatapere
# Processing Record 45 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 8 | san juan
# Processing Record 47 of Set 8 | lorica
# Processing Record 48 of Set 8 | saint-philippe
# Processing Record 49 of Set 8 | havoysund
# Processing Record 50 of Set 8 | boddam
# Processing Record 1 of Set 9 | bestobe
# Processing Record 2 of Set 9 | rawlins
# Processing Record 3 of Set 9 | souillac
# Processing Record 4 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 5 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 6 of Set 9 | katobu
# Processing Record 7 of Set 9 | dingle
# Processing Record 8 of Set 9 | harper
# Processing Record 9 of Set 9 | roald
# Processing Record 10 of Set 9 | yakima
# Processing Record 11 of Set 9 | odweyne
# Processing Record 12 of Set 9 | ericeira
# Processing Record 13 of Set 9 | duz
# City not found. Skipping...
# Processing Record 14 of Set 9 | coihueco
# Processing Record 15 of Set 9 | fortuna
# Processing Record 16 of Set 9 | gat
# Processing Record 17 of Set 9 | port lincoln
# Processing Record 18 of Set 9 | manono
# Processing Record 19 of Set 9 | lardos
# Processing Record 20 of Set 9 | puerto carreno
# Processing Record 21 of Set 9 | nome
# Processing Record 22 of Set 9 | vanimo
# Processing Record 23 of Set 9 | balikpapan
# Processing Record 24 of Set 9 | kysyl-syr
# Processing Record 25 of Set 9 | kailua
# Processing Record 26 of Set 9 | paredon
# Processing Record 27 of Set 9 | tambacounda
# Processing Record 28 of Set 9 | sciacca
# Processing Record 29 of Set 9 | geraldton
# Processing Record 30 of Set 9 | paamiut
# Processing Record 31 of Set 9 | cherkasskoye
# Processing Record 32 of Set 9 | sharanga
# Processing Record 33 of Set 9 | port-cartier
# Processing Record 34 of Set 9 | codrington
# Processing Record 35 of Set 9 | lalmohan
# Processing Record 36 of Set 9 | guerrero negro
# Processing Record 37 of Set 9 | mabaruma
# Processing Record 38 of Set 9 | auki
# Processing Record 39 of Set 9 | tailai
# Processing Record 40 of Set 9 | houston
# Processing Record 41 of Set 9 | matagami
# Processing Record 42 of Set 9 | bjornevatn
# Processing Record 43 of Set 9 | taoudenni
# Processing Record 44 of Set 9 | kilindoni
# Processing Record 45 of Set 9 | kolding
# Processing Record 46 of Set 9 | mosalsk
# Processing Record 47 of Set 9 | zhuhai
# Processing Record 48 of Set 9 | berlevag
# Processing Record 49 of Set 9 | swan hill
# Processing Record 50 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 10 | victor harbor
# Processing Record 2 of Set 10 | komsomolskiy
# Processing Record 3 of Set 10 | nadym
# Processing Record 4 of Set 10 | matay
# Processing Record 5 of Set 10 | chateaubelair
# Processing Record 6 of Set 10 | mehamn
# Processing Record 7 of Set 10 | kushiro
# Processing Record 8 of Set 10 | barranco
# Processing Record 9 of Set 10 | san angelo
# Processing Record 10 of Set 10 | sobolevo
# Processing Record 11 of Set 10 | xuddur
# Processing Record 12 of Set 10 | fujin
# Processing Record 13 of Set 10 | hobyo
# Processing Record 14 of Set 10 | sekondi
# Processing Record 15 of Set 10 | plouzane
# Processing Record 16 of Set 10 | turukhansk
# Processing Record 17 of Set 10 | edendale
# Processing Record 18 of Set 10 | taiobeiras
# Processing Record 19 of Set 10 | naryan-mar
# Processing Record 20 of Set 10 | ust-maya
# Processing Record 21 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 22 of Set 10 | mount isa
# Processing Record 23 of Set 10 | chokurdakh
# Processing Record 24 of Set 10 | berdigestyakh
# Processing Record 25 of Set 10 | ketchikan
# Processing Record 26 of Set 10 | magalia
# Processing Record 27 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 10 | sola
# Processing Record 29 of Set 10 | talnakh
# Processing Record 30 of Set 10 | dhidhdhoo
# Processing Record 31 of Set 10 | jiayuguan
# Processing Record 32 of Set 10 | tankhoy
# Processing Record 33 of Set 10 | svetlaya
# Processing Record 34 of Set 10 | guayaramerin
# Processing Record 35 of Set 10 | liberal
# Processing Record 36 of Set 10 | sao sebastiao
# Processing Record 37 of Set 10 | toora-khem
# Processing Record 38 of Set 10 | grenaa
# Processing Record 39 of Set 10 | tura
# Processing Record 40 of Set 10 | seddon
# Processing Record 41 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 10 | abaete
# Processing Record 43 of Set 10 | ardakan
# Processing Record 44 of Set 10 | hemsedal
# Processing Record 45 of Set 10 | padilla
# Processing Record 46 of Set 10 | japura
# Processing Record 47 of Set 10 | varhaug
# Processing Record 48 of Set 10 | radzyn podlaski
# Processing Record 49 of Set 10 | jalu
# Processing Record 50 of Set 10 | san blas
# Processing Record 1 of Set 11 | lobito
# Processing Record 2 of Set 11 | mahebourg
# Processing Record 3 of Set 11 | qiongshan
# Processing Record 4 of Set 11 | dicabisagan
# Processing Record 5 of Set 11 | luzhou
# Processing Record 6 of Set 11 | tual
# Processing Record 7 of Set 11 | shaoyang
# Processing Record 8 of Set 11 | henties bay
# Processing Record 9 of Set 11 | solnechnyy
# Processing Record 10 of Set 11 | beira
# Processing Record 11 of Set 11 | adre
# Processing Record 12 of Set 11 | itaituba
# Processing Record 13 of Set 11 | chalmette
# Processing Record 14 of Set 11 | nanakuli
# Processing Record 15 of Set 11 | shubarshi
# Processing Record 16 of Set 11 | chicama
# Processing Record 17 of Set 11 | jieshi
# Processing Record 18 of Set 11 | muisne
# Processing Record 19 of Set 11 | vestmannaeyjar
# Processing Record 20 of Set 11 | shatrovo
# Processing Record 21 of Set 11 | marabba
# Processing Record 22 of Set 11 | darasun
# Processing Record 23 of Set 11 | sun city west
# Processing Record 24 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 25 of Set 11 | milverton
# Processing Record 26 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 27 of Set 11 | kathmandu
# Processing Record 28 of Set 11 | sioux city
# Processing Record 29 of Set 11 | bozeman
# Processing Record 30 of Set 11 | kualakapuas
# Processing Record 31 of Set 11 | cam ranh
# Processing Record 32 of Set 11 | pacov
# Processing Record 33 of Set 11 | labis
# Processing Record 34 of Set 11 | viedma
# Processing Record 35 of Set 11 | cockburn town
# Processing Record 36 of Set 11 | bulgan
# Processing Record 37 of Set 11 | omsukchan
# Processing Record 38 of Set 11 | antofagasta
# Processing Record 39 of Set 11 | grindavik
# Processing Record 40 of Set 11 | troitsko-pechorsk
# Processing Record 41 of Set 11 | pendleton
# Processing Record 42 of Set 11 | ukiah
# Processing Record 43 of Set 11 | khudumelapye
# Processing Record 44 of Set 11 | deniliquin
# Processing Record 45 of Set 11 | chara
# Processing Record 46 of Set 11 | qui nhon
# Processing Record 47 of Set 11 | almaznyy
# Processing Record 48 of Set 11 | portland
# Processing Record 49 of Set 11 | canitas
# City not found. Skipping...
# Processing Record 50 of Set 11 | xucheng
# Processing Record 1 of Set 12 | snyder
# Processing Record 2 of Set 12 | ayagoz
# Processing Record 3 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 12 | hinesburg
# Processing Record 5 of Set 12 | zeya
# Processing Record 6 of Set 12 | san quintin
# Processing Record 7 of Set 12 | wanaka
# Processing Record 8 of Set 12 | terenga
# City not found. Skipping...
# Processing Record 9 of Set 12 | saint-augustin
# Processing Record 10 of Set 12 | shahrud
# Processing Record 11 of Set 12 | katha
# City not found. Skipping...
# Processing Record 12 of Set 12 | bahia blanca
# Processing Record 13 of Set 12 | dauriya
# Processing Record 14 of Set 12 | kirakira
# Processing Record 15 of Set 12 | artyom
# Processing Record 16 of Set 12 | cap malheureux
# Processing Record 17 of Set 12 | rochester
# Processing Record 18 of Set 12 | arman
# Processing Record 19 of Set 12 | ngunguru
# Processing Record 20 of Set 12 | barra patuca
# Processing Record 21 of Set 12 | nenjiang
# Processing Record 22 of Set 12 | ugoofaaru
# Processing Record 23 of Set 12 | teya
# Processing Record 24 of Set 12 | te anau
# Processing Record 25 of Set 12 | vrangel
# Processing Record 26 of Set 12 | biltine
# Processing Record 27 of Set 12 | la paz
# Processing Record 28 of Set 12 | xining
# Processing Record 29 of Set 12 | uruzgan
# Processing Record 30 of Set 12 | husavik
# Processing Record 31 of Set 12 | marystown
# Processing Record 32 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 12 | esso
# Processing Record 34 of Set 12 | mokhsogollokh
# Processing Record 35 of Set 12 | xudat
# Processing Record 36 of Set 12 | dolores
# Processing Record 37 of Set 12 | salta
# Processing Record 38 of Set 12 | mogadishu
# Processing Record 39 of Set 12 | payson
# Processing Record 40 of Set 12 | boyarka
# Processing Record 41 of Set 12 | comodoro rivadavia
# Processing Record 42 of Set 12 | iqaluit
# Processing Record 43 of Set 12 | alice springs
# Processing Record 44 of Set 12 | port macquarie
# Processing Record 45 of Set 12 | bere
# Processing Record 46 of Set 12 | haines junction
# Processing Record 47 of Set 12 | natal
# Processing Record 48 of Set 12 | ko samui
# Processing Record 49 of Set 12 | nador
# Processing Record 50 of Set 12 | antropovo
# Processing Record 1 of Set 13 | sinnamary
# Processing Record 2 of Set 13 | maues
# Processing Record 3 of Set 13 | gladstone
# Processing Record 4 of Set 13 | seoul
# Processing Record 5 of Set 13 | megion
# Processing Record 6 of Set 13 | zaysan
# Processing Record 7 of Set 13 | coihaique
# Processing Record 8 of Set 13 | quatre cocos
# Processing Record 9 of Set 13 | kloulklubed
# Processing Record 10 of Set 13 | merrill
# Processing Record 11 of Set 13 | lazaro cardenas
# Processing Record 12 of Set 13 | kaka
# Processing Record 13 of Set 13 | aygehovit
# Processing Record 14 of Set 13 | huicheng
# Processing Record 15 of Set 13 | bandar
# Processing Record 16 of Set 13 | erlangen
# Processing Record 17 of Set 13 | muros
# Processing Record 18 of Set 13 | san jose
# Processing Record 19 of Set 13 | christchurch
# Processing Record 20 of Set 13 | lavrentiya
# Processing Record 21 of Set 13 | banjar
# Processing Record 22 of Set 13 | siyabuswa
# Processing Record 23 of Set 13 | flin flon
# Processing Record 24 of Set 13 | havre
# Processing Record 25 of Set 13 | caboolture
# Processing Record 26 of Set 13 | kathu
# Processing Record 27 of Set 13 | tocopilla
# Processing Record 28 of Set 13 | villazon
# Processing Record 29 of Set 13 | emiliano zapata
# Processing Record 30 of Set 13 | ust-tsilma
# Processing Record 31 of Set 13 | mecca
# Processing Record 32 of Set 13 | onguday
# Processing Record 33 of Set 13 | hami
# Processing Record 34 of Set 13 | zory
# Processing Record 35 of Set 13 | vila franca do campo
# Processing Record 36 of Set 13 | gap
# Processing Record 37 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 13 | maningrida
# Processing Record 39 of Set 13 | salto del guaira
# Processing Record 40 of Set 13 | lingig
# Processing Record 41 of Set 13 | pahrump
# Processing Record 42 of Set 13 | sangar
# Processing Record 43 of Set 13 | noumea
# Processing Record 44 of Set 13 | avera
# Processing Record 45 of Set 13 | kahramanmaras
# Processing Record 46 of Set 13 | cerrito
# Processing Record 47 of Set 13 | yarada
# Processing Record 48 of Set 13 | quetigny
# Processing Record 49 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 50 of Set 13 | dondo
# Processing Record 1 of Set 14 | wanlaweyn
# Processing Record 2 of Set 14 | high prairie
# Processing Record 3 of Set 14 | nakhon phanom
# Processing Record 4 of Set 14 | kushmurun
# Processing Record 5 of Set 14 | thai binh
# Processing Record 6 of Set 14 | port-gentil
# Processing Record 7 of Set 14 | inirida
# Processing Record 8 of Set 14 | san rafael
# Processing Record 9 of Set 14 | marrakesh
# Processing Record 10 of Set 14 | presidencia roque saenz pena
# Processing Record 11 of Set 14 | new waterford
# Processing Record 12 of Set 14 | kimberley
# Processing Record 13 of Set 14 | westport
# Processing Record 14 of Set 14 | dahuk
# Processing Record 15 of Set 14 | abnub
# Processing Record 16 of Set 14 | atbasar
# Processing Record 17 of Set 14 | xuzhou
# Processing Record 18 of Set 14 | santa maria
# Processing Record 19 of Set 14 | ulaangom
# Processing Record 20 of Set 14 | merauke
# Processing Record 21 of Set 14 | sinjah
# City not found. Skipping...
# Processing Record 22 of Set 14 | lokosovo
# Processing Record 23 of Set 14 | totness
# Processing Record 24 of Set 14 | poum
# Processing Record 25 of Set 14 | emerald
# Processing Record 26 of Set 14 | tevaitoa
# Processing Record 27 of Set 14 | cervantes
# Processing Record 28 of Set 14 | san vicente
# Processing Record 29 of Set 14 | usinsk
# Processing Record 30 of Set 14 | napier
# Processing Record 31 of Set 14 | walvis bay
# Processing Record 32 of Set 14 | grand gaube
# Processing Record 33 of Set 14 | alto araguaia
# Processing Record 34 of Set 14 | dudinka
# Processing Record 35 of Set 14 | mlonggo
# Processing Record 36 of Set 14 | beringovskiy
# Processing Record 37 of Set 14 | honggang
# Processing Record 38 of Set 14 | palasa
# Processing Record 39 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 40 of Set 14 | myaundzha
# Processing Record 41 of Set 14 | isangel
# Processing Record 42 of Set 14 | ereymentau
# Processing Record 43 of Set 14 | manaure
# Processing Record 44 of Set 14 | olafsvik
# Processing Record 45 of Set 14 | bolondron
# Processing Record 46 of Set 14 | banugao
# Processing Record 47 of Set 14 | paramonga
# Processing Record 48 of Set 14 | taltal
# Processing Record 49 of Set 14 | hosanagara
# Processing Record 50 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 1 of Set 15 | berezovka
# Processing Record 2 of Set 15 | tessaoua
# Processing Record 3 of Set 15 | umm kaddadah
# Processing Record 4 of Set 15 | bilibino
# Processing Record 5 of Set 15 | bria
# Processing Record 6 of Set 15 | honningsvag
# Processing Record 7 of Set 15 | maceio
# Processing Record 8 of Set 15 | severobaykalsk
# Processing Record 9 of Set 15 | inhambane
# Processing Record 10 of Set 15 | rio branco do sul
# Processing Record 11 of Set 15 | san policarpo
# Processing Record 12 of Set 15 | raychikhinsk
# Processing Record 13 of Set 15 | sioux lookout
# Processing Record 14 of Set 15 | naifaru
# Processing Record 15 of Set 15 | eydhafushi
# Processing Record 16 of Set 15 | kazachinskoye
# Processing Record 17 of Set 15 | bonito
# Processing Record 18 of Set 15 | raudeberg
# Processing Record 19 of Set 15 | nioro
# Processing Record 20 of Set 15 | ostersund
# Processing Record 21 of Set 15 | san nicolas
# Processing Record 22 of Set 15 | yingkou
# Processing Record 23 of Set 15 | rovaniemi
# Processing Record 24 of Set 15 | biak
# Processing Record 25 of Set 15 | koboldo
# City not found. Skipping...
# Processing Record 26 of Set 15 | newton
# Processing Record 27 of Set 15 | leipzig
# Processing Record 28 of Set 15 | hervey bay
# Processing Record 29 of Set 15 | kulykiv
# Processing Record 30 of Set 15 | hebertville
# City not found. Skipping...
# Processing Record 31 of Set 15 | suntar
# Processing Record 32 of Set 15 | severomuysk
# Processing Record 33 of Set 15 | orangeburg
# Processing Record 34 of Set 15 | jamame
# Processing Record 35 of Set 15 | juifang
# City not found. Skipping...
# Processing Record 36 of Set 15 | beyneu
# Processing Record 37 of Set 15 | beloha
# Processing Record 38 of Set 15 | kangavar
# Processing Record 39 of Set 15 | shorkot
# Processing Record 40 of Set 15 | playa vicente
# Processing Record 41 of Set 15 | guozhen
# Processing Record 42 of Set 15 | diffa
# Processing Record 43 of Set 15 | qaqortoq
# Processing Record 44 of Set 15 | guarapari
# Processing Record 45 of Set 15 | labrea
# Processing Record 46 of Set 15 | luanda
# Processing Record 47 of Set 15 | sibiti
# Processing Record 48 of Set 15 | moindou
# Processing Record 49 of Set 15 | salto de agua
# Processing Record 50 of Set 15 | toba
# Processing Record 1 of Set 16 | kieta
# Processing Record 2 of Set 16 | abong mbang
# Processing Record 3 of Set 16 | coahuayana
# Processing Record 4 of Set 16 | adrar
# Processing Record 5 of Set 16 | eureka
# Processing Record 6 of Set 16 | zinder
# Processing Record 7 of Set 16 | alta floresta
# Processing Record 8 of Set 16 | musafirkhana
# Processing Record 9 of Set 16 | pasighat
# Processing Record 10 of Set 16 | gazojak
# Processing Record 11 of Set 16 | alenquer
# Processing Record 12 of Set 16 | houma
# Processing Record 13 of Set 16 | tautira
# Processing Record 14 of Set 16 | koryazhma
# Processing Record 15 of Set 16 | tinjah
# City not found. Skipping...
# Processing Record 16 of Set 16 | shakawe
# Processing Record 17 of Set 16 | bagdarin
# Processing Record 18 of Set 16 | fort saint john
# City not found. Skipping...
# Processing Record 19 of Set 16 | frystak
# Processing Record 20 of Set 16 | pleasant prairie
# Processing Record 21 of Set 16 | wahiawa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Ushuaia -54.8000  -68.3000     47.86        66          75
# 1          Chumikan  54.7183  135.3150      2.08        80         100
# 2           Aklavik  68.2191 -135.0107      1.40        78          75
# 3        Morant Bay  17.8815  -76.4093     76.62        77          28
# 4           Mazagao  -0.1150  -51.2894     80.65        81         100
# 5            Nyurba  63.2842  118.3319    -18.76        99          62
# 6       New Norfolk -42.7826  147.0587     55.90        76           2
# 7             Moree -29.4667  149.8500     71.62        68          40
# 8         Upernavik  72.7868  -56.1549     -4.58        74         100
# 9  Praia Da Vitoria  38.7333  -27.0667     61.75        77          75
#
#    Wind Speed Current Description Country                 Date
# 0       25.32       broken clouds      AR  2022-01-30 17:14:35
# 1       16.89     overcast clouds      RU  2022-01-30 17:14:35
# 2        5.75          light snow      CA  2022-01-30 17:14:36
# 3        8.37    scattered clouds      JM  2022-01-30 17:14:36
# 4        5.55       moderate rain      BR  2022-01-30 17:14:36
# 5        4.50       broken clouds      RU  2022-01-30 17:14:37
# 6        2.01           clear sky      AU  2022-01-30 17:14:37
# 7        6.91    scattered clouds      AU  2022-01-30 17:14:37
# 8        9.86     overcast clouds      GL  2022-01-30 17:14:38
# 9       22.19       broken clouds      PT  2022-01-30 17:14:38

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Ushuaia      AR -54.8000  -68.3000     47.86        66
# 1          Chumikan      RU  54.7183  135.3150      2.08        80
# 2           Aklavik      CA  68.2191 -135.0107      1.40        78
# 3        Morant Bay      JM  17.8815  -76.4093     76.62        77
# 4           Mazagao      BR  -0.1150  -51.2894     80.65        81
# 5            Nyurba      RU  63.2842  118.3319    -18.76        99
# 6       New Norfolk      AU -42.7826  147.0587     55.90        76
# 7             Moree      AU -29.4667  149.8500     71.62        68
# 8         Upernavik      GL  72.7868  -56.1549     -4.58        74
# 9  Praia Da Vitoria      PT  38.7333  -27.0667     61.75        77
#
#    Cloudiness  Wind Speed Current Description
# 0          75       25.32       broken clouds
# 1         100       16.89     overcast clouds
# 2          75        5.75          light snow
# 3          28        8.37    scattered clouds
# 4         100        5.55       moderate rain
# 5          62        4.50       broken clouds
# 6           2        2.01           clear sky
# 7          40        6.91    scattered clouds
# 8         100        9.86     overcast clouds
# 9          75       22.19       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
